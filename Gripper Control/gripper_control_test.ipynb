# %%
import serial
import time

# %%
#arduino = serial.Serial(port='COM4', baudrate=9600, timeout=.1)
arduino = serial.Serial(port='/dev/ttyACM0', baudrate=9600, timeout=.1)

def set_servo(servo_id, angle):
    command = f"S,{servo_id},{angle}\n"
    arduino.write(command.encode())

# %%
while True:
    set_servo(0, 90)
    if arduino.in_waiting > 0:
        line = arduino.readline().decode().strip()
        print("Arduino says:", line)
# Out:
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# Arduino says: Hi
# ...

# %%
set_servo(3, 100)

# %%
#move right finger
#angle [90, 180] (open, closed)
set_servo(0, 180)

# %%
#move left finger
#angle [120, 30] (open, closed)
set_servo(3, 30)

# %%
#move thumb
#angle [20, 100] (open, closed)
set_servo(4, 100)

# %%
#move angle right finger
#angle [120, 30] (opposite, corner)
set_servo(1, 120)

# %%
#move angle left finger
#angle [50, 140] (opposite, corner)
set_servo(2, 50)

# %%
#move angle corner
#angle [110] (middle) +-60
set_servo(5, 110)

# %%
iteration = 0
while iteration <=5: 
   
    set_servo(0, 170)
    time.sleep(0.01)
    
    set_servo(1, 90)
    time.sleep(0.01)
    
    set_servo(2, 80)
    time.sleep(0.01)
    
    set_servo(3, 40)
    time.sleep(0.01)
    
    set_servo(4,100)
    time.sleep(0.5)
    
    #set_servo(5, 90)
    #time.sleep(0.1)

    set_servo(0, 90)
    time.sleep(0.01)
    
    set_servo(1, 120)
    time.sleep(0.01)
    
    set_servo(2, 50)
    time.sleep(0.01)
    
    set_servo(3, 120)
    time.sleep(0.01)
    
    set_servo(4, 30)
    time.sleep(0.5)
    
    iteration +=1
    
    #set_servo(5, 120)
    #time.sleep(0.1)

# %%
set_servo(0, 170)
time.sleep(0.01)

set_servo(3, 40)
time.sleep(0.01)

set_servo(4,100)

# %%
set_servo(0, 90)
time.sleep(0.01)

set_servo(3, 120)
time.sleep(0.01)

set_servo(4, 30)
