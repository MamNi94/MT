# %%
import cv2

# %%
camera_capture = cv2.VideoCapture(2)

while True:
    ret, frame = camera_capture.read()
    cv2.imshow('test', frame)
    if cv2.waitKey(1) == 'q':
        break


camera_capture.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@38.896] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ERROR:0@38.993] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 5
#       3 while True:
#       4     ret, frame = camera_capture.read()
# ----> 5     cv2.imshow('test', frame)
#       6     if cv2.waitKey(0) == 'q':
#       7         break
#
# error: OpenCV(4.11.0) /io/opencv/modules/highgui/src/window.cpp:973: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'
